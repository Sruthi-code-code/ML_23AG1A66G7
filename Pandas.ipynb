# %% [markdown]
# Introduction to ML

# %% [markdown]
# pandas

# %%
import pandas as pd

# %% [markdown]
# csv file

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# Text File

# %%
df1 = pd.read_csv("/content/losspatience.txt", sep='\t')

# %%
df1.head()
# Out:
#                    Call centre users 'lose patience'
# 0  Customers trying to get through to call centre...
# 1  Once past the welcome message, callers on aver...
# 2  The surge in customers trying to get through t...
# 3  In what Dimension Data calls an "alarming deve...
# 4  Suggestions that "outsourcing" - relocating ca...

# %%
df1.tail()
# Out:
#                    Call centre users 'lose patience'
# 3  In what Dimension Data calls an "alarming deve...
# 4  Suggestions that "outsourcing" - relocating ca...
# 5  There are "no big differences in wait time and...
# 6  - call centre operations are part of their bus...
# 7   - they are worried about the risk of going ab...

# %%
df1.describe()
# Out:
#                         Call centre users 'lose patience'
# count                                                   8
# unique                                                  8
# top     Customers trying to get through to call centre...
# freq                                                    1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Call centre users 'lose patience'  8 non-null      object
# dtypes: object(1)
# memory usage: 196.0+ bytes

# %%
df1.columns
# Out:
# Index(['Call centre users 'lose patience''], dtype='object')

# %% [markdown]
# json file

# %%
df2=pd.read_json("/content/sample_data/anscombe.json")

# %%
df2.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
df2.tail()
# Out:
#    Series   X      Y
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# 42     IV   8   7.91
# 43     IV   8   6.89

# %%
df2.describe()
# Out:
#                X          Y
# count  44.000000  44.000000
# mean    9.000000   7.500455
# std     3.198837   1.959244
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Series  44 non-null     object
#  1   X       44 non-null     int64
#  2   Y       44 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df2.columns
# Out:
# Index(['Series', 'X', 'Y'], dtype='object')

# %% [markdown]
# Excel file

# %%
df3=pd.read_excel("/content/Project-Management-Sample-Data.xlsx")

# %%
df3.head()
# Out:
#    Unnamed: 0               Unnamed: 1 Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0         NaN        Excel Sample Data        NaN          NaN         NaN
# 1         NaN                      NaN        NaN          NaN         NaN
# 2         NaN  Project Management Data        NaN          NaN         NaN
# 3         NaN                      NaN        NaN          NaN         NaN
# 4         NaN             Project Name  Task Name  Assigned to  Start Date
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0            NaN        NaN        NaN
# 1            NaN        NaN        NaN
# 2            NaN        NaN        NaN
# 3            NaN        NaN        NaN
# 4  Days Required   End Date   Progress

# %%
df3.tail()
# Out:
#     Unnamed: 0   Unnamed: 1               Unnamed: 2 Unnamed: 3  \
# 46         NaN    Logistics  Transportation Planning   Patricia
# 47         NaN    Logistics   Inventory Optimization    Quentin
# 48         NaN  Engineering           Product Design     Rachel
# 49         NaN  Engineering       System Integration        Sam
# 50         NaN  Engineering        Prototype Testing        Tom
#
#              Unnamed: 4 Unnamed: 5           Unnamed: 6 Unnamed: 7
# 46  2024-01-29 00:00:00         30  2024-02-28 00:00:00          1
# 47  2024-03-29 00:00:00         20  2024-04-18 00:00:00          0
# 48  2024-01-02 00:00:00         25  2024-01-27 00:00:00        0.2
# 49  2024-02-02 00:00:00         22  2024-02-24 00:00:00          0
# 50  2024-02-23 00:00:00         27  2024-03-21 00:00:00          0

# %%
df3.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  49 non-null     object
#  2   Unnamed: 2  47 non-null     object
#  3   Unnamed: 3  47 non-null     object
#  4   Unnamed: 4  47 non-null     object
#  5   Unnamed: 5  47 non-null     object
#  6   Unnamed: 6  47 non-null     object
#  7   Unnamed: 7  47 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 3.3+ KB

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')
